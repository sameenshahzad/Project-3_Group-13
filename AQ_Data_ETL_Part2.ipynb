# %% [markdown]
# <!--  -->PART 2

# %%
# data from kaggle.com ('air-pollution' in 
# 'Resources folder')

# %%
import pandas as pd

# %% [markdown]
# # Health Impacts & Death Data

# %%
# read the csv
df = pd.read_csv("Resources/air-pollution/death-rates-from-air-pollution.csv")
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                            370.050474
# 1                                            358.978418
# 2                                            352.766453
# 3                                            357.055923
# 4                                            362.970439
# ...                                                 ...
# 6835                                         143.477957
# 6836                                         140.643245
# ...

# %%
# read the csv
df1 = pd.read_csv("Resources/air-pollution/disease-burden-by-risk-factor.csv")
df1
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       DALYs (Disability-Adjusted Life Years) - Cause: All causes - Risk: Low physical activity - Sex: Both - Age: All Ages (Number)  \
# 0                                          61720.058219
# 1                                          62191.602523
# 2                                          63325.234394
# 3                                          64873.624040
# 4                                          66452.067739
# ...                                                 ...
# 6835                                        7196.883376
# 6836                                        7424.673391
# ...

# %%
# read the csv
df2 = pd.read_csv("Resources/air-pollution/share-deaths-air-pollution.csv")
df2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: Age-standardized (Percent)
# 0                                             21.328446
# 1                                             21.011770
# 2                                             21.192810
# 3                                             21.367169
# 4                                             21.094811
# ...                                                 ...
# 6835                                          10.976388
# 6836                                          11.021700
# ...

# %%
# read the csv
df3 = pd.read_csv("Resources/air-pollution/death-rates-total-air-pollution.csv")
df3
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Air pollution - Sex: Both - Age: Age-standardized (Rate)
# 0                                            402.175651
# 1                                            390.085258
# 2                                            383.201196
# 3                                            387.704919
# 4                                            394.022027
# ...                                                 ...
# 6835                                         183.044625
# 6836                                         179.060638
# 6837                                         174.048806
# ...

# %%
# read the csv
df4 = pd.read_csv("Resources/air-pollution/number-of-deaths-by-risk-factor.csv")
df4
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: All Ages (Number)  \
# 0                                                  3169
# 1                                                  3222
# 2                                                  3395
# 3                                                  3623
# 4                                                  3788
# ...                                                 ...
# 6835                                               2835
# 6836                                               2781
# ...

# %%
# data from kaggle.com ('outdoor-air-pollution'in 
# 'Resources folder')

# %%
# read the csv
df5 = pd.read_csv("Resources/outdoor-air-pollution/ambient-pollution-death-rates-2017-1990.csv")
df5
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56390       Zimbabwe       ZWE  1988
# 56391       Zimbabwe       ZWE  1989
# 56392       Zimbabwe       ZWE  2020
# 56393       Zimbabwe       ZWE  2021
# 56394  Åland Islands       ALA  2015
#
#        Deaths - Cause: All causes - Risk: Outdoor air pollution - OWID - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                    NaN
# 1                                              37.403786
# 2                                              36.093797
# 3                                              35.128474
# 4                                              35.290047
# ...                                                  ...
# ...

# %%
# read the csv
df6 = pd.read_csv("Resources/outdoor-air-pollution/death-rate-from-pm25-vs-pm25-concentration.csv")
df6
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56546       Zimbabwe       ZWE  1988
# 56547       Zimbabwe       ZWE  1989
# 56548       Zimbabwe       ZWE  2020
# 56549       Zimbabwe       ZWE  2021
# 56550  Åland Islands       ALA  2015
#
#        Deaths - Cause: All causes - Risk: Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                    NaN
# 1                                              30.822693
# 2                                              29.826184
# 3                                              29.202030
# 4                                              29.429702
# ...                                                  ...
# ...

# %%
# read the csv
df6 = pd.read_csv("Resources/outdoor-air-pollution/death-rate-from-pm25-vs-pm25-concentration.csv")
df6
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  1990
# 2        Afghanistan       AFG  1991
# 3        Afghanistan       AFG  1992
# 4        Afghanistan       AFG  1993
# ...              ...       ...   ...
# 56546       Zimbabwe       ZWE  1988
# 56547       Zimbabwe       ZWE  1989
# 56548       Zimbabwe       ZWE  2020
# 56549       Zimbabwe       ZWE  2021
# 56550  Åland Islands       ALA  2015
#
#        Deaths - Cause: All causes - Risk: Ambient particulate matter pollution - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                    NaN
# 1                                              30.822693
# 2                                              29.826184
# 3                                              29.202030
# 4                                              29.429702
# ...                                                  ...
# ...

# %%
# read the csv
df7 = pd.read_csv("Resources/outdoor-air-pollution/death-rates-from-air-pollution.csv")
df7
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Deaths - Cause: All causes - Risk: Household air pollution from solid fuels - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                            370.050474
# 1                                            358.978418
# 2                                            352.766453
# 3                                            357.055923
# 4                                            362.970439
# ...                                                 ...
# 6835                                         143.477957
# 6836                                         140.643245
# ...

# %% [markdown]
# # Air Pollution Data

# %%
# read the csv
df8 = pd.read_csv("Resources/outdoor-air-pollution/emissions-of-air-pollutants (1).csv")
df8
# Out:
#             Entity Code  Year  PM₁₀ (Index)  PM₂.₅ (Index)  \
# 0   United Kingdom  GBR  1970        100.00         100.00
# 1   United Kingdom  GBR  1971         92.64          89.16
# 2   United Kingdom  GBR  1972         82.63          79.12
# 3   United Kingdom  GBR  1973         86.54          80.72
# 4   United Kingdom  GBR  1974         78.72          75.10
# ..             ...  ...   ...           ...            ...
# 73   United States  USA  2012         22.20          77.61
# 74   United States  USA  2013         22.18          77.37
# 75   United States  USA  2014         22.16          77.13
# 76   United States  USA  2015         21.91          75.89
# 77   United States  USA  2016         21.66          74.65
#
#     Non-methane volatile organic compounds (Index)  Nitrogen oxides (Index)  \
# 0                                           100.00                   100.00
# 1                                           100.42                    99.05
# ...

# %%
# read the csv
df9 = pd.read_csv("Resources/outdoor-air-pollution/emissions-of-air-pollutants.csv")
df9
# Out:
#             Entity Code  Year  PM₁₀ (Index)  PM₂.₅ (Index)  \
# 0   United Kingdom  GBR  1970        100.00         100.00
# 1   United Kingdom  GBR  1971         92.64          89.16
# 2   United Kingdom  GBR  1972         82.63          79.12
# 3   United Kingdom  GBR  1973         86.54          80.72
# 4   United Kingdom  GBR  1974         78.72          75.10
# ..             ...  ...   ...           ...            ...
# 73   United States  USA  2012         22.20          77.61
# 74   United States  USA  2013         22.18          77.37
# 75   United States  USA  2014         22.16          77.13
# 76   United States  USA  2015         21.91          75.89
# 77   United States  USA  2016         21.66          74.65
#
#     Non-methane volatile organic compounds (Index)  Nitrogen oxides (Index)  \
# 0                                           100.00                   100.00
# 1                                           100.42                    99.05
# ...

# %%
# read the csv
df10 = pd.read_csv("Resources/outdoor-air-pollution/exposure-pollution-above-who-targets.csv")
df10
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1995
# 2     Afghanistan  AFG  2000
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2010
# ...           ...  ...   ...
# 2503     Zimbabwe  ZWE  2013
# 2504     Zimbabwe  ZWE  2014
# 2505     Zimbabwe  ZWE  2015
# 2506     Zimbabwe  ZWE  2016
# 2507     Zimbabwe  ZWE  2017
#
#       PM2.5 pollution, population exposed to levels exceeding WHO Interim Target-1 value (% of total)  \
# 0                                             99.958321
# 1                                             99.959663
# 2                                             99.966713
# 3                                             99.931335
# 4                                             99.974632
# ...                                                 ...
# 2503                                           0.000000
# 2504                                           0.000000
# ...

# %%
# read the csv
df11 = pd.read_csv("Resources/outdoor-air-pollution/PM25-air-pollution.csv")
df11
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1995
# 2     Afghanistan  AFG  2000
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2010
# ...           ...  ...   ...
# 2503     Zimbabwe  ZWE  2013
# 2504     Zimbabwe  ZWE  2014
# 2505     Zimbabwe  ZWE  2015
# 2506     Zimbabwe  ZWE  2016
# 2507     Zimbabwe  ZWE  2017
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)
# 0                                             65.486794
# 1                                             65.179512
# 2                                             64.922462
# 3                                             64.522682
# 4                                             65.245590
# ...                                                 ...
# 2503                                          23.111088
# 2504                                          22.805950
# 2505                                          21.733709
# ...

# %%
# read the csv
df12 = pd.read_csv("Resources/outdoor-air-pollution/pm-exposure-1990-2017.csv")
df12
# Out:
#              Entity      Code  Year  \
# 0          Abkhazia  OWID_ABK  2015
# 1       Afghanistan       AFG  1990
# 2       Afghanistan       AFG  1995
# 3       Afghanistan       AFG  2000
# 4       Afghanistan       AFG  2005
# ...             ...       ...   ...
# 2594       Zimbabwe       ZWE  2014
# 2595       Zimbabwe       ZWE  2015
# 2596       Zimbabwe       ZWE  2016
# 2597       Zimbabwe       ZWE  2017
# 2598  Åland Islands       ALA  2015
#
#       PM2.5 air pollution, mean annual exposure (micrograms per cubic meter)  \
# 0                                                   NaN
# 1                                             65.486794
# 2                                             65.179512
# 3                                             64.922462
# 4                                             64.522682
# ...                                                 ...
# 2594                                          22.805950
# ...

# %%
# read the csv
df13 = pd.read_csv("Resources/outdoor-air-pollution/share-above-who-pollution-guidelines.csv")
df13
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1995
# 2     Afghanistan  AFG  2000
# 3     Afghanistan  AFG  2005
# 4     Afghanistan  AFG  2010
# ...           ...  ...   ...
# 2503     Zimbabwe  ZWE  2013
# 2504     Zimbabwe  ZWE  2014
# 2505     Zimbabwe  ZWE  2015
# 2506     Zimbabwe  ZWE  2016
# 2507     Zimbabwe  ZWE  2017
#
#       PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)
# 0                                                 100.0
# 1                                                 100.0
# 2                                                 100.0
# 3                                                 100.0
# 4                                                 100.0
# ...                                                 ...
# 2503                                              100.0
# 2504                                              100.0
# 2505                                              100.0
# ...
