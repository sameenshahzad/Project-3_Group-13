# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Ambient_Air_Quality_Data

# %%
df1 = pd.read_csv('Data/Ambient_Air_Quality_Data.csv')
df1
# Out:
#         aq_id                        Region ISO3       Country        City  \
# 0          A1  Eastern Mediterranean Region  AFG   Afghanistan       Kabul
# 1          A2               European Region  ALB       Albania      Durres
# 2          A3               European Region  ALB       Albania      Durres
# 3          A4               European Region  ALB       Albania     Elbasan
# 4          A5               European Region  ALB       Albania     Elbasan
# ...       ...                           ...  ...           ...         ...
# 32186  A32187                African Region  ZAF  South Africa  West Coast
# 32187  A32188                African Region  ZAF  South Africa  West Coast
# 32188  A32189                African Region  ZAF  South Africa  West Coast
# 32189  A32190                African Region  ZAF  South Africa  West Coast
# 32190  A32191                African Region  ZAF  South Africa   West Rand
#
#        Measurement Year    PM25   PM10    NO2
# ...

# %%
df1 = df1.rename(columns={'Measurement Year': 'Year'})

# %%
df1.columns
# Out:
# Index(['aq_id', 'Region', 'ISO3', 'Country', 'City', 'Year', 'PM25', 'PM10',
#        'NO2'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32191 entries, 0 to 32190
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   aq_id    32191 non-null  object
#  1   Region   32191 non-null  object
#  2   ISO3     32191 non-null  object
#  3   Country  32191 non-null  object
#  4   City     32191 non-null  object
#  5   Year     32191 non-null  int64
#  6   PM25     32191 non-null  float64
#  7   PM10     32191 non-null  float64
#  8   NO2      32191 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.2+ MB

# %%
# save the DataFrame to a CSV file with index set to False
# df1.to_csv('Ambient_Air_Quality_Data.csv', index=False)

# %% [markdown]
# AQ_Pollution_Mortality_Data

# %%
df2 = pd.read_csv('Data/AQ_Pollution_Mortality_Data.csv')
df2
# Out:
#     mor_id      Country  ISO3  Death_Rate_Ranking  Total_Pollution_Deaths  \
# 0       M1  Afghanistan   AFG                  30                   44247
# 1       M2      Albania   ALB                  92                    2269
# 2       M3      Algeria   DZA                 159                   17940
# 3       M4      Andorra   AND                 140                      45
# 4       M5       Angola   AGO                  49                   30842
# ..     ...          ...   ...                 ...                     ...
# 183   M184    Venezuela   VEN                 155                   14871
# 184   M185      Vietnam   VNM                 103                   71365
# 185   M186        Yemen   YEM                  50                   29038
# 186   M187       Zambia   ZMB                  58                   16600
# 187   M188     Zimbabwe   ZWE                  54                   16518
#
#      Air_Pollution_Deaths  Water_Pollution_Deaths  \
# ...

# %%
df2.columns
# Out:
# Index(['mor_id', 'Country', 'ISO3', 'Death_Rate_Ranking',
#        'Total_Pollution_Deaths', 'Air_Pollution_Deaths',
#        'Water_Pollution_Deaths', 'Occupational_Pollution_Deaths',
#        'Lead_Deaths'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mor_id                         188 non-null    object
#  1   Country                        188 non-null    object
#  2   ISO3                           188 non-null    object
#  3   Death_Rate_Ranking             188 non-null    int64
#  4   Total_Pollution_Deaths         188 non-null    int64
#  5   Air_Pollution_Deaths           188 non-null    int64
#  6   Water_Pollution_Deaths         188 non-null    int64
#  7   Occupational_Pollution_Deaths  188 non-null    int64
#  8   Lead_Deaths                    188 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 13.3+ KB

# %%
# df2.to_csv('AQ_Pollution_Mortality_Data.csv', index=False)

# %% [markdown]
# Countries_Codes_and_Coordinates

# %%
df3 = pd.read_csv('Data/Countries Codes and Coordinates.csv')
df3
# Out:
#     coor_id            Country Alpha-2 code Alpha-3 code  Numeric code  \
# 0       LL1        Afghanistan           AF          AFG             4
# 1       LL2            Albania           AL          ALB             8
# 2       LL3            Algeria           DZ          DZA            12
# 3       LL4     American Samoa           AS          ASM            16
# 4       LL5            Andorra           AD          AND            20
# ..      ...                ...          ...          ...           ...
# 250   LL251  Wallis and Futuna           WF          WLF           876
# 251   LL252     Western Sahara           EH          ESH           732
# 252   LL253              Yemen           YE          YEM           887
# 253   LL254             Zambia           ZM          ZMB           894
# 254   LL255           Zimbabwe           ZW          ZWE           716
#
#      Latitude (average)  Longitude (average)
# 0               33.0000                 65.0
# ...

# %%
df3 = df3.rename(columns={
    'Alpha-2 code': 'alpha_2_code',
    'Alpha-3 code': 'alpha_3_code',
    'Numeric code': 'numeric_code',
    'Latitude (average)': 'latitude',
    'Longitude (average)': 'longitude'
})

# %%
df3['alpha_2_code'] = df3['alpha_2_code'].fillna(value='NA')

# %%
df3.columns
# Out:
# Index(['coor_id', 'Country', 'alpha_2_code', 'alpha_3_code', 'numeric_code',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   coor_id       255 non-null    object
#  1   Country       255 non-null    object
#  2   alpha_2_code  255 non-null    object
#  3   alpha_3_code  255 non-null    object
#  4   numeric_code  255 non-null    int64
#  5   latitude      255 non-null    float64
#  6   longitude     255 non-null    float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 14.1+ KB

# %%
# df3.to_csv('Countries_Codes_and_Coordinates.csv', index=False)

# %% [markdown]
# Death-Rates-from-Air_Pollution

# %%
df4 = pd.read_csv('Data/death-rates-from-air-pollution.csv')
df4
# Out:
#        dap_id      Country ISO3  Year  Household_Air_Pollution_Deaths  \
# 0        DAP1  Afghanistan  AFG  1990                      370.050474
# 1        DAP2  Afghanistan  AFG  1991                      358.978418
# 2        DAP3  Afghanistan  AFG  1992                      352.766453
# 3        DAP4  Afghanistan  AFG  1993                      357.055923
# 4        DAP5  Afghanistan  AFG  1994                      362.970439
# ...       ...          ...  ...   ...                             ...
# 6835  DAP6836     Zimbabwe  ZWE  2015                      143.477957
# 6836  DAP6837     Zimbabwe  ZWE  2016                      140.643245
# 6837  DAP6838     Zimbabwe  ZWE  2017                      137.448374
# 6838  DAP6839     Zimbabwe  ZWE  2018                      133.923031
# 6839  DAP6840     Zimbabwe  ZWE  2019                      130.508301
#
#       Ambient_Particulate_Matter_Pollution_Deaths  Air Pollution_Deaths  \
# ...

# %%
df4 = df4.rename(columns={'Air Pollution_Deaths': 'Air_Pollution_Deaths'})

# %%
df4['ISO3'] = df4['ISO3'].fillna(value='NA')

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 8 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   dap_id                                       6840 non-null   object
#  1   Country                                      6840 non-null   object
#  2   ISO3                                         6840 non-null   object
#  3   Year                                         6840 non-null   int64
#  4   Household_Air_Pollution_Deaths               6840 non-null   float64
#  5   Ambient_Particulate_Matter_Pollution_Deaths  6840 non-null   float64
#  6   Air_Pollution_Deaths                         6840 non-null   float64
#  7   Ambient_Ozone_Pollution_Deaths               6840 non-null   float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 427.6+ KB

# %%
# df4.to_csv('Death-Rates-from-Air_Pollution.csv', index=False)

# %% [markdown]
# Disease_Burden_by_Risk_Factor

# %%
df5 = pd.read_csv('Data/disease_burden_by_risk_factor.csv')
df5
# Out:
#           Country ISO3  Year  DALYs_Low_Physical_Activity  \
# 0     Afghanistan  AFG  1990                 61720.058219
# 1     Afghanistan  AFG  1991                 62191.602523
# 2     Afghanistan  AFG  1992                 63325.234394
# 3     Afghanistan  AFG  1993                 64873.624040
# 4     Afghanistan  AFG  1994                 66452.067739
# ...           ...  ...   ...                          ...
# 6835     Zimbabwe  ZWE  2015                  7196.883376
# 6836     Zimbabwe  ZWE  2016                  7424.673391
# 6837     Zimbabwe  ZWE  2017                  7655.216366
# 6838     Zimbabwe  ZWE  2018                  7862.559712
# 6839     Zimbabwe  ZWE  2019                  8126.406128
#
#       DALYs_Non-Exclusive_Breastfeeding  DALYs_Air_Pollution  \
# 0                         197049.343187         1.986290e+06
# 1                         222485.786219         2.069430e+06
# 2                         271585.194354         2.298508e+06
# ...

# %%
df5['ISO3'] = df5['ISO3'].fillna(value='NA')

# %%
df5.columns
# Out:
# Index(['Country', 'ISO3', 'Year', 'DALYs_Low_Physical_Activity',
#        'DALYs_Non-Exclusive_Breastfeeding', 'DALYs_Air_Pollution',
#        'DALYs_Child_Wasting', 'DALYs_High_Systolic_BP',
#        'DALYs_High_Fasting_Glucose', 'DALYs_Child_Stunting',
#        'DALYs_High_Body_Mass_Index', 'DALYS_Secondhand_Smoke',
#        'DALYs_Unsafe_Sanitation', 'DALYs_Unsafe_Water_Source',
#        'DALYs_Diet_Low_in-Vegetables', 'DALYs_Diet_Low_in_Fruits',
#        'DALYs_Diet_High_in_Sodium', 'DALYs_Drug_Use',
#        'DALYs_Household_Air_Pollution_from_Solid_Fuels',
#        'DALYs_High_LDL_Cholesterol', 'DALYs_Iron_Deficiency',
#        'DALYs_Zinc_Deficiency', 'DALYs_Smoking', 'DALYs_VitaminA_Deficiency',
#        'DALYs_Particulate_Matter_Pollution'],
#       dtype='object')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 25 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         6840 non-null   object
#  1   ISO3                                            6840 non-null   object
#  2   Year                                            6840 non-null   int64
#  3   DALYs_Low_Physical_Activity                     6840 non-null   float64
#  4   DALYs_Non-Exclusive_Breastfeeding               6840 non-null   float64
#  5   DALYs_Air_Pollution                             6840 non-null   float64
#  6   DALYs_Child_Wasting                             6840 non-null   float64
#  7   DALYs_High_Systolic_BP                          6840 non-null   float64
#  8   DALYs_High_Fasting_Glucose                      6840 non-null   float64
# ...

# %%
# df5.to_csv('Disease_Burden_by_Risk_Factor.csv', index=False)

# %% [markdown]
# Number_of_Deaths_by_Risk_Factor

# %%
df6 = pd.read_csv('Data/deaths_by_risk_factor.csv')
df6
# Out:
#           Country ISO3  Year  Deaths_from_Outdoor_Air_Pollution  \
# 0     Afghanistan  AFG  1990                               3169
# 1     Afghanistan  AFG  1991                               3222
# 2     Afghanistan  AFG  1992                               3395
# 3     Afghanistan  AFG  1993                               3623
# 4     Afghanistan  AFG  1994                               3788
# ...           ...  ...   ...                                ...
# 6835     Zimbabwe  ZWE  2015                               2835
# 6836     Zimbabwe  ZWE  2016                               2781
# 6837     Zimbabwe  ZWE  2017                               2700
# 6838     Zimbabwe  ZWE  2018                               2669
# 6839     Zimbabwe  ZWE  2019                               2680
#
#       Deaths_from_High_Systolic_Blood_Pressure  Deaths_from_High_Sodium_Diet  \
# 0                                        25633                          1045
# ...

# %%
df6 = df6.rename(columns={'Deaths_from_No_Access_to_Handwashing Facility': 'Deaths_from_No_Access_to_Handwashing_Facility'})

# %%
df6['ISO3'] = df6['ISO3'].fillna(value='NA')

# %%
df6.columns
# Out:
# Index(['Country', 'ISO3', 'Year', 'Deaths_from_Outdoor_Air_Pollution',
#        'Deaths_from_High_Systolic_Blood_Pressure',
#        'Deaths_from_High_Sodium_Diet', 'Deaths_from_Low_Whole_Grains_Diet',
#        'Deaths_from_Alcohol_Use', 'Deaths_from_Low_Fruits_Diet',
#        'Deaths_from_Unsafe_Water_Source', 'Deaths_from_Secondhand_Smoke',
#        'Death_from_Low_Birth_Weight', 'Deaths_from_Child_Wasting',
#        'Deaths_from_Unsafe_Sex', 'Deaths_from_Diet_low_in_nuts_and_seeds',
#        'Death_from_Household_Air_Pollution_from_Solid_Fuels',
#        'Deaths_from_Diet_Low_in_Vegetables', 'Deaths_Low_Physical_Activity',
#        'Deaths_from__Smoking', 'Deaths_from_High_Fasting_Plasma_Glucose',
#        'Deaths_from_Air_Pollution', 'Deaths_from_High_Body_Mass_Index',
#        'Deaths_from_Unsafe_Sanitation',
#        'Deaths_from_No_Access_to_Handwashing_Facility', 'Deaths_from_Drug_Use',
#        'Deaths_from_Low_Bone_Mineral_Density',
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 31 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Country                                              6840 non-null   object
#  1   ISO3                                                 6840 non-null   object
#  2   Year                                                 6840 non-null   int64
#  3   Deaths_from_Outdoor_Air_Pollution                    6840 non-null   int64
#  4   Deaths_from_High_Systolic_Blood_Pressure             6840 non-null   int64
#  5   Deaths_from_High_Sodium_Diet                         6840 non-null   int64
#  6   Deaths_from_Low_Whole_Grains_Diet                    6840 non-null   int64
#  7   Deaths_from_Alcohol_Use                              6840 non-null   int64
# ...

# %%
# df6.to_csv('Number_of_Deaths_by_Risk_Factor.csv', index=False)

# %% [markdown]
# Outdoor_Air_Death_Rates_by_Age

# %%
# read the csv
df7 = pd.read_csv("Data/outdoor_air_death_rates_by_age.csv")
df7
# Out:
#       OAD_id      Country ISO3  Year    Under_5  5_to_14_years   70+_years  \
# 0        DA1  Afghanistan  AFG  1990  53.513443       0.772926  258.285326
# 1        DA2  Afghanistan  AFG  1991  48.115794       0.781314  252.993731
# 2        DA3  Afghanistan  AFG  1992  44.290436       0.802953  248.153433
# 3        DA4  Afghanistan  AFG  1993  43.980623       0.811577  247.668589
# 4        DA5  Afghanistan  AFG  1994  43.744352       0.790209  250.505987
# ...      ...          ...  ...   ...        ...            ...         ...
# 6835  DA6836     Zimbabwe  ZWE  2015  40.182696       0.463899  301.418735
# 6836  DA6837     Zimbabwe  ZWE  2016  38.165762       0.476214  291.492273
# 6837  DA6838     Zimbabwe  ZWE  2017  35.788257       0.467371  280.556991
# 6838  DA6839     Zimbabwe  ZWE  2018  34.269344       0.459083  273.146813
# 6839  DA6840     Zimbabwe  ZWE  2019  33.604821       0.434262  269.186080
#
#       15_to_49_years  50_to_69_years
# ...

# %%
df7 = df7.rename(columns={'70+_years': '70plus_years'})

# %%
df7['ISO3'] = df7['ISO3'].fillna(value='NA')

# %%
df7.columns
# Out:
# Index(['OAD_id', 'Country', 'ISO3', 'Year', 'Under_5', '5_to_14_years',
#        '70plus_years', '15_to_49_years', '50_to_69_years'],
#       dtype='object')

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OAD_id          6840 non-null   object
#  1   Country         6840 non-null   object
#  2   ISO3            6840 non-null   object
#  3   Year            6840 non-null   int64
#  4   Under_5         6840 non-null   float64
#  5   5_to_14_years   6840 non-null   float64
#  6   70plus_years    6840 non-null   float64
#  7   15_to_49_years  6840 non-null   float64
#  8   50_to_69_years  6840 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 481.1+ KB

# %%
# df7.to_csv('Outdoor_Air_Death_Rates_by_Age.csv', index=False)
